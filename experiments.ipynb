# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
from tree.base import DecisionTree
from tree.metrics import *
from sklearn.model_selection import train_test_split

np.random.seed(42)
num_average_time = 100

# %%
N = [200,300,400,500]
M = [2, 4, 6, 8]

# %% [markdown]
# DISCRETE INPUT DISCRETE OUTPUT

# %%
train_time_matrix = []
pred_time_matrix = []

for i in N:
    train_row = []
    pred_row = []
    for j in M:
        training_time = []
        pred_time = []
        for k in range(num_average_time):
            x = pd.DataFrame(np.random.randint(0, 3, (i, j)))
            y = pd.Series(np.random.randint(0, 3, i))
            x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
            tree = DecisionTree(criterion='entropy', max_depth=5)

            start_training_time = time.time()
            tree.fit(x_train, y_train)
            end_training_time = time.time()

            start_pred_time = time.time()
            y_pred = tree.predict(x_test)
            end_pred_time = time.time()

            training_time.append(end_training_time - start_training_time)
            pred_time.append(end_pred_time - start_pred_time)

        avg_train = sum(training_time)/len(training_time)
        avg_pred = sum(pred_time)/len(pred_time)

        train_row.append(avg_train)
        pred_row.append(avg_pred)
        print("No. of samples(N)", i)
        print("No. of features(M)", j)
        print("Average training time:",avg_train)
        print("Average prediction time:",avg_pred)

    train_time_matrix.append(train_row)
    pred_time_matrix.append(pred_row)

# Plotting
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(N, [row[0] for row in train_time_matrix], marker='o', label='Training Time')
plt.plot(N, [row[0] for row in pred_time_matrix], marker='s', label='Prediction Time')
plt.title('Time vs N (M={})'.format(M[0]))
plt.xlabel('Number of Samples (N)')
plt.ylabel('Time (seconds)')
plt.legend()

plt.subplot(1,2,2)
plt.plot(M, train_time_matrix[0], marker='o', label='Training Time')
plt.plot(M, pred_time_matrix[0], marker='s', label='Prediction Time')
plt.title('Time vs M (N={})'.format(N[0]))
plt.xlabel('Number of Features (M)')
plt.ylabel('Time (seconds)')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# No. of samples(N) 200
# No. of features(M) 2
# Average training time: 0.01172795295715332
# Average prediction time: 0.0005048036575317383
# No. of samples(N) 200
# No. of features(M) 4
# Average training time: 0.08052489757537842
# Average prediction time: 0.0005042076110839844
# No. of samples(N) 200
# No. of features(M) 6
# Average training time: 0.1878382921218872
# Average prediction time: 0.0005423307418823242
# No. of samples(N) 200
# No. of features(M) 8
# Average training time: 0.25459182262420654
# Average prediction time: 0.0005754947662353516
# No. of samples(N) 300
# No. of features(M) 2
# Average training time: 0.009269165992736816
# Average prediction time: 0.0005017995834350586
# No. of samples(N) 300
# No. of features(M) 4
# Average training time: 0.08862650394439697
# Average prediction time: 0.0006983280181884766
# No. of samples(N) 300
# No. of features(M) 6
# Average training time: 0.2397242784500122
# Average prediction time: 0.0007265806198120117
# No. of samples(N) 300
# No. of features(M) 8
# Average training time: 0.3274195909500122
# Average prediction time: 0.0007412910461425781
# No. of samples(N) 400
# No. of features(M) 2
# Average training time: 0.008783960342407226
# Average prediction time: 0.0006325006484985352
# No. of samples(N) 400
# No. of features(M) 4
# Average training time: 0.09157474040985107
# Average prediction time: 0.0008861541748046875
# No. of samples(N) 400
# No. of features(M) 6
# Average training time: 0.2949572324752808
# Average prediction time: 0.000935506820678711
# No. of samples(N) 400
# No. of features(M) 8
# Average training time: 0.41880414485931394
# Average prediction time: 0.0010230541229248047
# No. of samples(N) 500
# No. of features(M) 2
# Average training time: 0.009590220451354981
# Average prediction time: 0.0007009506225585938
# No. of samples(N) 500
# No. of features(M) 4
# Average training time: 0.09450767040252686
# Average prediction time: 0.0010018348693847656
# No. of samples(N) 500
# No. of features(M) 6
# Average training time: 1.458194088935852
# Average prediction time: 0.005615043640136719
# No. of samples(N) 500
# No. of features(M) 8
# Average training time: 0.48089962005615233
# Average prediction time: 0.0012322664260864258

# %% [markdown]
# REAL INPUT DISCRETE OUTPUT

# %%
train_time_matrix = []
pred_time_matrix = []

for i in N:
    train_row = []
    pred_row = []
    for j in M:
        training_time = []
        pred_time = []
        for k in range(num_average_time):
            x = pd.DataFrame(np.random.rand(i, j))
            y = pd.Series(np.random.randint(0, 3, i))
            x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
            tree = DecisionTree(criterion='entropy', max_depth=5)

            start_training_time = time.time()
            tree.fit(x_train, y_train)
            end_training_time = time.time()

            start_pred_time = time.time()
            y_pred = tree.predict(x_test)
            end_pred_time = time.time()

            training_time.append(end_training_time - start_training_time)
            pred_time.append(end_pred_time - start_pred_time)

        avg_train = sum(training_time)/len(training_time)
        avg_pred = sum(pred_time)/len(pred_time)

        train_row.append(avg_train)
        pred_row.append(avg_pred)
        print("No. of samples(N)", i)
        print("No. of features(M)", j)
        print("Average training time:",avg_train)
        print("Average prediction time:",avg_pred)

    train_time_matrix.append(train_row)
    pred_time_matrix.append(pred_row)

# Plotting
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(N, [row[0] for row in train_time_matrix], marker='o', label='Training Time')
plt.plot(N, [row[0] for row in pred_time_matrix], marker='s', label='Prediction Time')
plt.title('Time vs N (M={})'.format(M[0]))
plt.xlabel('Number of Samples (N)')
plt.ylabel('Time (seconds)')
plt.legend()

plt.subplot(1,2,2)
plt.plot(M, train_time_matrix[0], marker='o', label='Training Time')
plt.plot(M, pred_time_matrix[0], marker='s', label='Prediction Time')
plt.title('Time vs M (N={})'.format(N[0]))
plt.xlabel('Number of Features (M)')
plt.ylabel('Time (seconds)')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# No. of samples(N) 200
# No. of features(M) 2
# Average training time: 0.20290350914001465
# Average prediction time: 0.0004820108413696289
# No. of samples(N) 200
# No. of features(M) 4
# Average training time: 0.6692778825759887
# Average prediction time: 0.000654292106628418
# No. of samples(N) 200
# No. of features(M) 6
# Average training time: 1.2669035196304321
# Average prediction time: 0.0007545232772827148
# No. of samples(N) 200
# No. of features(M) 8
# Average training time: 1.880507516860962
# Average prediction time: 0.0007076501846313476
# No. of samples(N) 300
# No. of features(M) 2
# Average training time: 0.30609066486358644
# Average prediction time: 0.0006372451782226563
# No. of samples(N) 300
# No. of features(M) 4
# Average training time: 5.046741080284119
# Average prediction time: 0.0053835630416870115
# No. of samples(N) 300
# No. of features(M) 6
# Average training time: 2.7635913372039793
# Average prediction time: 0.0010876417160034179
# No. of samples(N) 300
# No. of features(M) 8
# Average training time: 2.8931478023529054
# Average prediction time: 0.001036214828491211
# No. of samples(N) 400
# No. of features(M) 2
# Average training time: 0.4126835823059082
# Average prediction time: 0.0007558822631835938
# No. of samples(N) 400
# No. of features(M) 4
# Average training time: 1.3705832481384277
# Average prediction time: 0.0011339902877807618
# No. of samples(N) 400
# No. of features(M) 6
# Average training time: 2.7365519285202025
# Average prediction time: 0.0013274431228637695
# No. of samples(N) 400
# No. of features(M) 8
# Average training time: 10.741849350929261
# Average prediction time: 0.0040030241012573246
# No. of samples(N) 500
# No. of features(M) 2
# Average training time: 0.5136265993118286
# Average prediction time: 0.0009252786636352539
# No. of samples(N) 500
# No. of features(M) 4
# Average training time: 1.5501835107803346
# Average prediction time: 0.0013907909393310546
# No. of samples(N) 500
# No. of features(M) 6
# Average training time: 5.3371896028518675
# Average prediction time: 0.002628183364868164
# No. of samples(N) 500
# No. of features(M) 8
# Average training time: 7.972046566009522
# Average prediction time: 0.0027527093887329103

# %% [markdown]
# DISCRETE INPUT REAL OUTPUT

# %%
train_time_matrix = []
pred_time_matrix = []

for i in N:
    train_row = []
    pred_row = []
    for j in M:
        training_time = []
        pred_time = []
        for k in range(num_average_time):
            x = pd.DataFrame(np.random.randint(0, 3, (i, j)))
            y = pd.Series(np.random.rand(i))
            x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
            tree = DecisionTree(criterion='entropy', max_depth=5)

            start_training_time = time.time()
            tree.fit(x_train, y_train)
            end_training_time = time.time()

            start_pred_time = time.time()
            y_pred = tree.predict(x_test)
            end_pred_time = time.time()

            training_time.append(end_training_time - start_training_time)
            pred_time.append(end_pred_time - start_pred_time)

        avg_train = sum(training_time)/len(training_time)
        avg_pred = sum(pred_time)/len(pred_time)

        train_row.append(avg_train)
        pred_row.append(avg_pred)
        print("No. of samples(N)", i)
        print("No. of features(M)", j)
        print("Average training time:",avg_train)
        print("Average prediction time:",avg_pred)

    train_time_matrix.append(train_row)
    pred_time_matrix.append(pred_row)

# Plotting
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(N, [row[0] for row in train_time_matrix], marker='o', label='Training Time')
plt.plot(N, [row[0] for row in pred_time_matrix], marker='s', label='Prediction Time')
plt.title('Time vs N (M={})'.format(M[0]))
plt.xlabel('Number of Samples (N)')
plt.ylabel('Time (seconds)')
plt.legend()

plt.subplot(1,2,2)
plt.plot(M, train_time_matrix[0], marker='o', label='Training Time')
plt.plot(M, pred_time_matrix[0], marker='s', label='Prediction Time')
plt.title('Time vs M (N={})'.format(N[0]))
plt.xlabel('Number of Features (M)')
plt.ylabel('Time (seconds)')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# No. of samples(N) 200
# No. of features(M) 2
# Average training time: 0.008849120140075684
# Average prediction time: 0.0004700660705566406
# No. of samples(N) 200
# No. of features(M) 4
# Average training time: 0.058823156356811526
# Average prediction time: 0.0005135297775268555
# No. of samples(N) 200
# No. of features(M) 6
# Average training time: 0.15091869831085206
# Average prediction time: 0.0005664587020874024
# No. of samples(N) 200
# No. of features(M) 8
# Average training time: 0.2063297986984253
# Average prediction time: 0.0005464553833007812
# No. of samples(N) 300
# No. of features(M) 2
# Average training time: 0.005981874465942383
# Average prediction time: 0.00044653415679931643
# No. of samples(N) 300
# No. of features(M) 4
# Average training time: 0.0597057580947876
# Average prediction time: 0.0006387710571289062
# No. of samples(N) 300
# No. of features(M) 6
# Average training time: 0.18899307250976563
# Average prediction time: 0.0007678031921386719
# No. of samples(N) 300
# No. of features(M) 8
# Average training time: 0.2771904706954956
# Average prediction time: 0.0008372306823730469
# No. of samples(N) 400
# No. of features(M) 2
# Average training time: 0.006051111221313477
# Average prediction time: 0.0005532741546630859
# No. of samples(N) 400
# No. of features(M) 4
# Average training time: 0.0626593828201294
# Average prediction time: 0.0008147239685058593
# No. of samples(N) 400
# No. of features(M) 6
# Average training time: 0.21807358264923096
# Average prediction time: 0.0009577989578247071
# No. of samples(N) 400
# No. of features(M) 8
# Average training time: 0.3054023504257202
# Average prediction time: 0.0009567499160766602
# No. of samples(N) 500
# No. of features(M) 2
# Average training time: 0.006115341186523437
# Average prediction time: 0.0006589651107788086
# No. of samples(N) 500
# No. of features(M) 4
# Average training time: 0.0643242597579956
# Average prediction time: 0.001083707809448242
# No. of samples(N) 500
# No. of features(M) 6
# Average training time: 0.2287141799926758
# Average prediction time: 0.0012558460235595702
# No. of samples(N) 500
# No. of features(M) 8
# Average training time: 0.3206374406814575
# Average prediction time: 0.0011255502700805663

# %% [markdown]
# REAL INPUT REAL OUTPUT

# %%
train_time_matrix = []
pred_time_matrix = []

for i in N:
    train_row = []
    pred_row = []
    for j in M:
        training_time = []
        pred_time = []
        for k in range(num_average_time):
            x = pd.DataFrame(np.random.rand(i, j))
            y = pd.Series(np.random.rand(i))
            x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
            tree = DecisionTree(criterion='entropy', max_depth=5)

            start_training_time = time.time()
            tree.fit(x_train, y_train)
            end_training_time = time.time()

            start_pred_time = time.time()
            y_pred = tree.predict(x_test)
            end_pred_time = time.time()

            training_time.append(end_training_time - start_training_time)
            pred_time.append(end_pred_time - start_pred_time)

        avg_train = sum(training_time)/len(training_time)
        avg_pred = sum(pred_time)/len(pred_time)

        train_row.append(avg_train)
        pred_row.append(avg_pred)
        print("No. of samples(N)", i)
        print("No. of features(M)", j)
        print("Average training time:",avg_train)
        print("Average prediction time:",avg_pred)

    train_time_matrix.append(train_row)
    pred_time_matrix.append(pred_row)

# Plotting
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(N, [row[0] for row in train_time_matrix], marker='o', label='Training Time')
plt.plot(N, [row[0] for row in pred_time_matrix], marker='s', label='Prediction Time')
plt.title('Time vs N (M={})'.format(M[0]))
plt.xlabel('Number of Samples (N)')
plt.ylabel('Time (seconds)')
plt.legend()

plt.subplot(1,2,2)
plt.plot(M, train_time_matrix[0], marker='o', label='Training Time')
plt.plot(M, pred_time_matrix[0], marker='s', label='Prediction Time')
plt.title('Time vs M (N={})'.format(N[0]))
plt.xlabel('Number of Features (M)')
plt.ylabel('Time (seconds)')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# No. of samples(N) 200
# No. of features(M) 2
# Average training time: 0.08209941387176514
# Average prediction time: 0.0004529237747192383
# No. of samples(N) 200
# No. of features(M) 4
# Average training time: 0.26531569957733153
# Average prediction time: 0.0008712291717529296
# No. of samples(N) 200
# No. of features(M) 6
# Average training time: 0.5264423608779907
# Average prediction time: 0.0007929086685180664
# No. of samples(N) 200
# No. of features(M) 8
# Average training time: 0.7730645895004272
# Average prediction time: 0.0007414340972900391
# No. of samples(N) 300
# No. of features(M) 2
# Average training time: 0.11795585155487061
# Average prediction time: 0.0006161689758300781
# No. of samples(N) 300
# No. of features(M) 4
# Average training time: 0.3959661960601807
# Average prediction time: 0.0008562088012695312
# No. of samples(N) 300
# No. of features(M) 6
# Average training time: 0.797607684135437
# Average prediction time: 0.0010322332382202148
# No. of samples(N) 300
# No. of features(M) 8
# Average training time: 2.3222426891326906
# Average prediction time: 0.0017503261566162109
# No. of samples(N) 400
# No. of features(M) 2
# Average training time: 0.16190569400787352
# Average prediction time: 0.0007330894470214844
# No. of samples(N) 400
# No. of features(M) 4
# Average training time: 0.5247669219970703
# Average prediction time: 0.0010943889617919921
# No. of samples(N) 400
# No. of features(M) 6
# Average training time: 1.1179208517074586
# Average prediction time: 0.0014195680618286134
# No. of samples(N) 400
# No. of features(M) 8
# Average training time: 1.6075173139572143
# Average prediction time: 0.0012980461120605468
# No. of samples(N) 500
# No. of features(M) 2
# Average training time: 0.8614998102188111
# Average prediction time: 0.003663969039916992
# No. of samples(N) 500
# No. of features(M) 4
# Average training time: 2.510721755027771
# Average prediction time: 0.0042798519134521484
# No. of samples(N) 500
# No. of features(M) 6
# Average training time: 1.3180930614471436
# Average prediction time: 0.001612687110900879
# No. of samples(N) 500
# No. of features(M) 8
# Average training time: 3.4153642416000367
# Average prediction time: 0.0028114080429077148
